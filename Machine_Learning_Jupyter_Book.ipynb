# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("Dog.jpg")
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(new_img)

# %%
import numpy as np
k1 = np.array([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])
filtered_img = cv2.filter2D(img,-1,k1)
plt.imshow(filtered_img)

# %%
blur_img = cv2.blur(img,(2,2))
plt.imshow(blur_img)

# %%
plt.subplot(1, 3, 1)
plt.imshow(new_img)
plt.title('Original Image')
plt.axis('off')

# Plotting the filtered image
plt.subplot(1, 3, 2)
plt.imshow(filtered_img)
plt.title('Filtered Image')
plt.axis('off')

# Plotting the blurred image
plt.subplot(1, 3, 3)
plt.imshow(blur_img)
plt.title('Blurred Image')
plt.axis('off')



plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread("Dog.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Box blur
blurred_img = cv2.blur(img,(10,10))

# Gaussian Blur
blurred_img2 = cv2.GaussianBlur(img,(5,5),0)

# Median Blur
blurred_img3 = cv2.medianBlur(img,3)

# subplot (Row,Col,Sequence)
plt.subplot(2,2,1),plt.imshow(img),plt.title("Original Image"),plt.axis('off')
plt.subplot(2,2,2),plt.imshow(blurred_img),plt.title("Box Image"),plt.axis('off')
plt.subplot(2,2,3),plt.imshow(blurred_img2),plt.title("Gaussian Image"),plt.axis('off')
plt.subplot(2,2,4),plt.imshow(blurred_img3),plt.title("Median Image"),plt.axis('off')
# Out:
# (<AxesSubplot:title={'center':'Median Image'}>,
# ...
#  Text(0.5, 1.0, 'Median Image'),
#  (-0.5, 274.5, 182.5, -0.5))

# %%
img = cv2.imread("Dog.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1 = np.ones((10,10))/100
# k1 = np.ones((8,8),np.float32)/64

print(k1)
blurred_img=cv2.filter2D(img,-1,k1)
plt.axis('off')
plt.imshow(blurred_img)
# Out:
# [[0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]
#  [0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01]]
